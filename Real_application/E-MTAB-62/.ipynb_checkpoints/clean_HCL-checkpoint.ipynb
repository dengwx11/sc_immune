# %%
setwd('/gpfs/loomis/pi/zhao2/wd262/shared_data/HCL/seurat_object/integrate_seurat_obj/protein_coding')

# %%
## bladder
data <- readRDS('./Adult-Prostate_protein_coding_integrated_rmbatch.rds')

# %%
head(data@meta.data)
# Out:
#                                    orig.ident    nCount_RNA nFeature_RNA
# AdultProstate_1.AGGACTAGATGGGAGATC AdultProstate 2311       1097
# AdultProstate_1.CTCGCAGCCTAGGTCCCG AdultProstate 2032        901
# AdultProstate_1.CTCGCACATCCCAAGCGG AdultProstate 2322       1214
# AdultProstate_1.AAGCGGTCGTAAGTCGGT AdultProstate 1815        970
# AdultProstate_1.AAGCGGACGTTGTAGTCG AdultProstate 3308       1306
# AdultProstate_1.CTCGCATATGTAAAGTAC AdultProstate 2252       1224
#                                    Cell_barcode       Sample
# AdultProstate_1.AGGACTAGATGGGAGATC AGGACTAGATGGGAGATC AdultProstate
# AdultProstate_1.CTCGCAGCCTAGGTCCCG CTCGCAGCCTAGGTCCCG AdultProstate
# AdultProstate_1.CTCGCACATCCCAAGCGG CTCGCACATCCCAAGCGG AdultProstate
# AdultProstate_1.AAGCGGTCGTAAGTCGGT AAGCGGTCGTAAGTCGGT AdultProstate
# AdultProstate_1.AAGCGGACGTTGTAGTCG AAGCGGACGTTGTAGTCG AdultProstate
# AdultProstate_1.CTCGCATATGTAAAGTAC CTCGCATATGTAAAGTAC AdultProstate
# ...

# %%
table(data$Celltype_Merge)
# Out:
#                   Basal cell             Endothelial cell
#                           31                          101
#              Epithelial cell                   Fibroblast
#                           40                            7
# Intermediate epithelial cell                 Luminal cell
#                          433                          187
#                M1 Macrophage          Neuroendocrine cell
#                          115                          375
#                   Neutrophil           Smooth muscle cell
#                           21                           28
#                       T cell                      Unknown
#                           32                          476
#      Unknown epithelial cell
#                          599

# %%
## Bone marrow
data <- readRDS('Fetal-Lung_protein_coding_integrated_rmbatch.rds')

# %%
table(data$Celltype_Merge)
# Out:
#                         Airway smooth muscle cell
#                                               253
#                                   Basal stem cell
#                                                16
#                                        CD8 T cell
#                                               316
#                                       Chondrocyte
#                                                45
#                                      Distal  cell
#                                                45
#                            Distal progenitor cell
#                                               772
#                                  Endothelial cell
#                                               452
#                                    Erythroid cell
#                                                53
#                                        Fibroblast
#                                               312
# Lung mesenchyme cell (cardiopulmonary progenitor)
# ...

# %%
## Brain cerenellum
data<-readRDS('Adult-Uterus_protein_coding_integrated_rmbatch.rds')
unique(data$Celltype_Merge)
# Out:
#  [1] "Endothelial cell"            "Endometrial cell"
#  [3] "Smooth muscle cell"          "Epithelial cell"
#  [5] "Unknown"                     "Unknown epithelial cell"
#  [7] "M1 Macrophage"               "T cell"
#  [9] "Stromal cell"                "Fibroblast"
# [11] "Vascular smooth muscle cell" "Endothelial cell in EMT"
# [13] "Mast cell"

# %%
unique(data$Celltype_Merge)
# Out:
#  [1] "Oligodendrocyte"                 "Epithelial cell"
#  [3] "Macrophage"                      "Neuthrophil"
#  [5] "Interneuron"                     "Astrocyte(Bergmann glia)"
#  [7] "Microglia"                       "Inhibitory neuron"
#  [9] "Oligodendrocyte progenitor cell" "Smooth muscle cell"
# [11] "B cell"                          "Endothelial cell"
# [13] "T cell"                          "Astrocyte"
# [15] "Stromal cell"                    "Excitatory neuron"

# %%
data2 <- readRDS('../protein_coding_new_celltype/Adult-Cerebellum_protein_coding_integrated_rmbatch.rds')

# %%
head(data2@meta.data)
# Out:
#                                      orig.ident      nCount_RNA nFeature_RNA
# AdultCerebellum_1.ACGAGCATTCCAACGTTG AdultCerebellum 6359       2949
# AdultCerebellum_1.TGCGGACGCACCGCCTAG AdultCerebellum 8261       2762
# AdultCerebellum_1.AACCTAACACCCAGTCGT AdultCerebellum 2816        992
# AdultCerebellum_1.AAGCGGCGTGGCTGATCA AdultCerebellum 3339       1813
# AdultCerebellum_1.AACCTAGCTCAAGTGGTA AdultCerebellum 3196       1842
# AdultCerebellum_1.TCGTAACCTTTCTCGTAA AdultCerebellum 3259       1613
#                                      Cell_barcode       Sample
# AdultCerebellum_1.ACGAGCATTCCAACGTTG ACGAGCATTCCAACGTTG AdultCerebellum
# AdultCerebellum_1.TGCGGACGCACCGCCTAG TGCGGACGCACCGCCTAG AdultCerebellum
# AdultCerebellum_1.AACCTAACACCCAGTCGT AACCTAACACCCAGTCGT AdultCerebellum
# AdultCerebellum_1.AAGCGGCGTGGCTGATCA AAGCGGCGTGGCTGATCA AdultCerebellum
# AdultCerebellum_1.AACCTAGCTCAAGTGGTA AACCTAGCTCAAGTGGTA AdultCerebellum
# ...

# %%
data3 <- readRDS('/gpfs/ysm/home/bl666/HCL/Pseudo_Bulk/BM_ImmuneCell_updated.rds')

# %%
head(data3@meta.data)
# Out:
#                                 orig.ident nCount_RNA nFeature_RNA
# BoneMarrow_1.CGGCAGCCAGACAACGCC BoneMarrow  765        461
# BoneMarrow_1.CTGTGTAAGCGGCCGACG BoneMarrow 2772       1162
# BoneMarrow_1.CGCACCTCGTAAAGTCGT BoneMarrow  462        309
# BoneMarrow_1.ACAATACGGCAGGGCTGC BoneMarrow 2625       1002
# BoneMarrow_1.GTCCCGGGACATTCACTT BoneMarrow  477        347
# BoneMarrow_1.CCGACGACGTTGGGGCGA BoneMarrow  806        546
#                                 Cell_barcode       Sample
# BoneMarrow_1.CGGCAGCCAGACAACGCC CGGCAGCCAGACAACGCC AdultBoneMarrow
# BoneMarrow_1.CTGTGTAAGCGGCCGACG CTGTGTAAGCGGCCGACG AdultBoneMarrow
# BoneMarrow_1.CGCACCTCGTAAAGTCGT CGCACCTCGTAAAGTCGT AdultBoneMarrow
# BoneMarrow_1.ACAATACGGCAGGGCTGC ACAATACGGCAGGGCTGC AdultBoneMarrow
# BoneMarrow_1.GTCCCGGGACATTCACTT GTCCCGGGACATTCACTT AdultBoneMarrow
# BoneMarrow_1.CCGACGACGTTGGGGCGA CCGACGACGTTGGGGCGA AdultBoneMarrow
#                                 Batch
# BoneMarrow_1.CGGCAGCCAGACAACGCC AdultBoneMarrow1
# ...

# %%
tissue_list <- c('Adult-Bladder','Adult-Cerebellum','Adult-Bone-Marrow')
input_seur <- c('Adult-Bladder_protein_coding_integrated_rmbatch.rds',
               'Adult-Bone-Marrow_protein_coding_integrated_rmbatch.rds',
               'Adult-Cerebellum_protein_coding_integrated_rmbatch.rds')
dat_csv <- read.csv('/gpfs/ysm/pi/zhao-data/wd262/sc_immune/sc_immune/Real_application/E-MTAB-62/Celltype_annotation_all.csv')

# %%
tissue_list <- c('Adult-Prostate','Fetal-Skin','Adult-Uterus')
input_seur <- c('Adult-Prostate_protein_coding_integrated_rmbatch.rds',
               'Fetal-Skin_protein_coding_integrated_rmbatch.rds',
               'Adult-Uterus_protein_coding_integrated_rmbatch.rds')
dat_csv <- read.csv('/gpfs/ysm/pi/zhao-data/wd262/sc_immune/sc_immune/Real_application/E-MTAB-62/Celltype_annotation_all.csv')

# %%
tissue_list <- c('Cord-Blood','Cord-Blood-CD34P')
input_seur <- c('Cord-Blood_protein_coding_integrated_rmbatch.rds','Cord-Blood-CD34P_protein_coding_integrated_rmbatch.rds'
               )
dat_csv <- read.csv('/gpfs/ysm/pi/zhao-data/wd262/sc_immune/sc_immune/Real_application/E-MTAB-62/Celltype_annotation_all.csv')

# %%
tissue_list <- c('Fetal-Lung')
input_seur <- c('Fetal-Lung_protein_coding_integrated_rmbatch.rds')
dat_csv <- read.csv('/gpfs/ysm/pi/zhao-data/wd262/sc_immune/sc_immune/Real_application/E-MTAB-62/Celltype_annotation_all.csv')

# %%
dat_csv[,1] <- as.character(dat_csv[,1])
dat_csv[,2] <- as.character(dat_csv[,2])

# %%
library(Seurat)
for(i in 1:length(input_seur)){
#i=1
    idx <- grep(tissue_list[i],input_seur)
#idx <-i
print(input_seur[idx])
    if(length(idx) !=1 ) next
    seur <- readRDS(paste0(
        '/gpfs/loomis/pi/zhao2/wd262/shared_data/HCL/seurat_object/integrate_seurat_obj/protein_coding/',input_seur[idx]))
    celltype_list<-dat_csv[dat_csv$tissue %in% tissue_list[i],]
    new_celltype <- sapply(seur$Celltype_Merge, function(x) celltype_list[celltype_list[,1] %in% x,2])
    #print(head(new_celltype))                       
    #new_celltype <- droplevels(new_celltype)                      
    names(new_celltype) <- NULL
    seur <- AddMetaData(seur, new_celltype, col.name= 'new_celltype') 
    print(head(seur@meta.data))                       
    saveRDS(seur, paste0(
        '/gpfs/loomis/pi/zhao2/wd262/shared_data/HCL/seurat_object/integrate_seurat_obj/protein_coding_new_celltype/',input_seur[idx]))                      
}
# Out:
# [1] "Fetal-Lung_protein_coding_integrated_rmbatch.rds"
#                                orig.ident nCount_RNA nFeature_RNA
# FetalLung_1.CCGACGTGTGCGGAATTA  FetalLung       3311         1705
# FetalLung_1.CATGATCATCCCAAAACG  FetalLung       2512         1340
# FetalLung_1.GGACATTATGTATAGCAT  FetalLung       3073         1679
# FetalLung_1.CGCTTGAGTCGTCGTGGC  FetalLung       2684         1215
# FetalLung_1.TGAAGCTGAAGCAGATGG  FetalLung       2600         1364
# FetalLung_1.GTATACCCTTTCTGATCA  FetalLung       2866         1604
#                                      Cell_barcode    Sample      Batch
# FetalLung_1.CCGACGTGTGCGGAATTA CCGACGTGTGCGGAATTA FetalLung FetalLung1
# FetalLung_1.CATGATCATCCCAAAACG CATGATCATCCCAAAACG FetalLung FetalLung1
# FetalLung_1.GGACATTATGTATAGCAT GGACATTATGTATAGCAT FetalLung FetalLung1
# FetalLung_1.CGCTTGAGTCGTCGTGGC CGCTTGAGTCGTCGTGGC FetalLung FetalLung1
# FetalLung_1.TGAAGCTGAAGCAGATGG TGAAGCTGAAGCAGATGG FetalLung FetalLung1
# ...

# %%
str(new_celltype)
# Out:
#  Named chr [1:9647] "(DELETED)" "(DELETED)" "Endothelial cell" "Macrophage" ...
#  - attr(*, "names")= chr [1:9647] "FetalLung_1.CCGACGTGTGCGGAATTA" "FetalLung_1.CATGATCATCCCAAAACG" "FetalLung_1.GGACATTATGTATAGCAT" "FetalLung_1.CGCTTGAGTCGTCGTGGC" ...

# %%
files <- list.files('/gpfs/loomis/pi/zhao2/wd262/shared_data/HCL/seurat_object/integrate_seurat_obj/protein_coding_new_celltype',full.names = TRUE)

# %%
s <- readRDS(input_seur[1])

# %%
head(s@meta.data)
# Out:
#                                     orig.ident     nCount_RNA nFeature_RNA
# CordBloodCD34P_1.AGGACTTGCAATCGAGTA CordBloodCD34P 3299       1006
# CordBloodCD34P_1.CTCGCAATTCCAAAAGTT CordBloodCD34P 3159        947
# CordBloodCD34P_1.CTGTGTATCTCTGTAATG CordBloodCD34P 2749        830
# CordBloodCD34P_1.CTGTGTGCAGGATGTGCG CordBloodCD34P 2601        941
# CordBloodCD34P_1.CTCGCACGTGGCCACAAG CordBloodCD34P 2414        748
# CordBloodCD34P_1.CTGTGTGTCGGTCCGCTA CordBloodCD34P 2087        726
#                                     Cell_barcode       Sample
# CordBloodCD34P_1.AGGACTTGCAATCGAGTA AGGACTTGCAATCGAGTA CordBloodCD34P
# CordBloodCD34P_1.CTCGCAATTCCAAAAGTT CTCGCAATTCCAAAAGTT CordBloodCD34P
# CordBloodCD34P_1.CTGTGTATCTCTGTAATG CTGTGTATCTCTGTAATG CordBloodCD34P
# CordBloodCD34P_1.CTGTGTGCAGGATGTGCG CTGTGTGCAGGATGTGCG CordBloodCD34P
# CordBloodCD34P_1.CTCGCACGTGGCCACAAG CTCGCACGTGGCCACAAG CordBloodCD34P
# CordBloodCD34P_1.CTGTGTGTCGGTCCGCTA CTGTGTGTCGGTCCGCTA CordBloodCD34P
# ...

# %%
for(i in 1:length(input_seur)){
    print(i)
    s <- readRDS(paste0('/gpfs/loomis/pi/zhao2/wd262/shared_data/HCL/seurat_object/integrate_seurat_obj/protein_coding_new_celltype/',input_seur[i]))
    Celltype_used <- s$new_celltype
    s@meta.data$Celltype_used <- Celltype_used 
    saveRDS(s,files[i])
}
# Out:
# [1] 1

# %%
head(files[1])
# Out:
# [1] "/gpfs/loomis/pi/zhao2/wd262/shared_data/HCL/seurat_object/integrate_seurat_obj/protein_coding_new_celltype/Adult-Adipose_protein_coding_integrated_rmbatch.rds"

# %%
tissue_list <- read.table('/gpfs/loomis/pi/zhao2/wd262/shared_data/HCL/tissue_list.txt')

# %%
tissue_list <- as.character(tissue_list[,1])
tissue_list <- sapply(tissue_list, function(x) substring(x,1,nchar(x)-1))

# %%
names(tissue_list) <- NULL
tissue_list <- unique(tissue_list)

# %%
str(tissue_list)
# Out:
#  chr [1:60] "Adult-Adipose" "Adult-Adrenal-Gland" "Adult-Artery" ...

# %%
files <- list.files('/gpfs/loomis/pi/zhao2/wd262/shared_data/HCL/seurat_object/integrate_seurat_obj/protein_coding_new_celltype',full.names = TRUE)
celltype_used_lists <- list()
used_tissue <- c()
k=1
used_files <- c()
for(i in 1:length(tissue_list)){
    print(tissue_list[i])
    idx <- grep(tissue_list[i],files)
    if(length(idx) !=1 ) next
    used_tissue <- c(used_tissue, tissue_list[i])
    s <- readRDS(files[idx])
    celltype_used_lists[[k]] <- unique(s$Celltype_used)
    k=k+1
    used_files <- c(used_files,files[idx])
}
# Out:
# [1] "Adult-Adipose"
# [1] "Adult-Adrenal-Gland"
# [1] "Adult-Artery"
# [1] "Adult-Ascending-Colon"
# [1] "Adult-Bladder"
# [1] "Adult-Bone-Marrow"
# [1] "Adult-Cerebellum"
# [1] "Adult-Cervix"
# [1] "Adult-Colon"
# [1] "Adult-Duodenum"
# [1] "Adult-Epityphlon"
# [1] "Adult-Esophagus"
# [1] "Adult-Fallopiantube"
# [1] "Adult-Gallbladder"
# [1] "Adult-Heart"
# [1] "Adult-Ileum"
# [1] "Adult-Jejunum"
# [1] "Adult-Kidney"
# [1] "Adult-Liver"
# [1] "Adult-Lung"
# [1] "Adult-Muscle"
# [1] "Adult-Omentum"
# [1] "Adult-Pancreas"
# [1] "Adult-Peripheral-Blood"
# [1] "Adult-Pleura"
# [1] "Adult-Prostate"
# [1] "Adult-Rectum"
# [1] "Adult-Sigmoid-Colon"
# [1] "Adult-Spleen"
# [1] "Adult-Stomach"
# [1] "Adult-Temporal-Lobe"
# [1] "Adult-Thyroid"
# [1] "Adult-Trachea"
# [1] "Adult-Transverse-Colon"
# [1] "Adult-Ureter"
# [1] "Adult-Uterus"
# [1] "Chorionic-Villus"
# [1] "Cord-Blood-CD34P"
# [1] "Cord-Blood"
# [1] "Fetal-Adrenal-Gland"
# [1] "Fetal-Brain"
# [1] "Fetal-Calvaria"
# [1] "Fetal-Eyes"
# ...

# %%
names(celltype_used_lists)<- used_tissue

# %%
write.table(cbind(used_tissue,used_files),'/gpfs/loomis/pi/zhao2/wd262/shared_data/bulk/E-MTAB-62/file_tissue_list.txt',quote = F, col.names = T, row.names = F)

# %%
cbind(used_tissue,used_files)
# Out:
#       used_tissue
#  [1,] Adult-Adipose
#  [2,] Adult-Adrenal-Gland
#  [3,] Adult-Artery
#  [4,] Adult-Bladder
#  [5,] Adult-Bone-Marrow
#  [6,] Adult-Cerebellum
#  [7,] Adult-Colon
#  [8,] Adult-Esophagus
#  [9,] Adult-Heart
# [10,] Adult-Ileum
# [11,] Adult-Kidney
# [12,] Adult-Lung
# [13,] Adult-Muscle
# [14,] Adult-Pancreas
# [15,] Adult-Peripheral-Blood
# [16,] Adult-Prostate
# [17,] Adult-Spleen
# [18,] Adult-Stomach
# [19,] Adult-Thyroid
# [20,] Adult-Uterus
# [21,] Cord-Blood-CD34P
# [22,] Fetal-Brain
# [23,] Fetal-Intestine
# [24,] Fetal-Skin
#       used_files
#  [1,] /gpfs/loomis/pi/zhao2/wd262/shared_data/HCL/seurat_object/integrate_seurat_obj/protein_coding_new_celltype/Adult-Adipose_protein_coding_integrated_rmbatch.rds
#  [2,] /gpfs/loomis/pi/zhao2/wd262/shared_data/HCL/seurat_object/integrate_seurat_obj/protein_coding_new_celltype/Adult-Adrenal-Gland_protein_coding_integrated_rmbatch.rds
# ...

# %%
celltype_used_lists
# Out:
# $`Adult-Adipose`
# [1] "Stromal cell"       "Mast cell"          "Adipocyte"
# [4] "Macrophage"         "Proliferating cell" "Neutrophil"
#
# $`Adult-Adrenal-Gland`
# [1] "Stromal cell"
#
# $`Adult-Artery`
#  [1] "Endothelial cell"   "Basal cell"         "B cell"
#  [4] "Macrophage"         "Fibroblast"         "Smooth muscle cell"
#  [7] "Mast cell"          "Stromal cell"       "Epithelial cell"
# [10] "T cell"
#
# $`Adult-Bladder`
#  [1] Urothelial cell     Smooth muscle cell  Macrophage
#  [4] Endothelial cell    Stromal cell        B cell
#  [7] Natural killer cell Mast cell           Fibroblast
# [10] Neutrophil          T cell
# 11 Levels: B cell Endothelial cell Fibroblast Macrophage ... Urothelial cell
#
# $`Adult-Bone-Marrow`
# [1] B cell              Erythroid cell      Neutrophil
# [4] T cell              Macrophage          Monocyte
# [7] HSPC                Natural killer cell Dendritic cell
# 9 Levels: B cell Dendritic cell Erythroid cell HSPC Macrophage ... T cell
#
# ...

# %%
saveRDS(celltype_used_lists,'/gpfs/loomis/pi/zhao2/wd262/shared_data/bulk/E-MTAB-62/celltype_used_lists.rds')

# %%
celltype_used_lists <- readRDS('/gpfs/loomis/pi/zhao2/wd262/shared_data/bulk/E-MTAB-62/celltype_used_lists.rds')
