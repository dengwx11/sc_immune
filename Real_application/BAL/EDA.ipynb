# %%
dir <- '/gpfs/loomis/pi/zhao2/cs2629/SARC_BAL'
bulk.rawcount <- read.table(paste0(dir,"/rawcounts_matrix_corrected_BAL209_withAnnot.txt"))

# %%
head(bulk.rawcount)
# Out:
#   V1        V2
# 1 GeneID    Chr
# 2 DDX11L1   chr1;chr1;chr1
# 3 WASH7P    chr1;chr1;chr1;chr1;chr1;chr1;chr1;chr1;chr1;chr1;chr1
# 4 MIR6859-3 chr1;chr1;chr15;chr16
# 5 MIR6859-2 chr1;chr1;chr15;chr16
# 6 MIR6859-1 chr1;chr1;chr15;chr16
#   V3
# 1 Start
# 2 11874;12613;13221
# 3 14362;14970;15796;16607;16858;17233;17606;17915;18268;24738;29321
# 4 17369;187891;101973524;17052
# 5 17369;187891;101973524;17052
# 6 17369;187891;101973524;17052
#   V4
# 1 End
# 2 12227;12721;14409
# 3 14829;15038;15947;16765;17055;17368;17742;18061;18366;24891;29370
# 4 17436;187958;101973591;17119
# 5 17436;187958;101973591;17119
# 6 17436;187958;101973591;17119
#   V5                    V6     V7          V8          V9          V10
# 1 Strand                Length 01B9020_010 01B9021_011 01B9022_001 01B9023_012
# 2 +;+;+                 1652   7           8           15          18
# 3 -;-;-;-;-;-;-;-;-;-;- 1769   858         869         1505        1863
# ...

# %%
truth <- readRDS(paste0(dir,"/celldiff.rds"))

# %%
truth
# Out:
#     GRADSID ALVBALD1  EOSBALD1   LYMBALD1   NEUBALD1
# 1   01S001        NaN        NaN        NaN        NaN
# 2   01S002        NaN        NaN        NaN        NaN
# 3   01S003        NaN        NaN        NaN        NaN
# 4   01S007        NaN        NaN        NaN        NaN
# 5   01S008        NaN        NaN        NaN        NaN
# 6   01S009        NaN        NaN        NaN        NaN
# 7   01S012        NaN        NaN        NaN        NaN
# 8   01S013        NaN        NaN        NaN        NaN
# 9   01S017        NaN        NaN        NaN        NaN
# 10  01S018        NaN        NaN        NaN        NaN
# 11  01S019        NaN        NaN        NaN        NaN
# 12  01S020        NaN        NaN        NaN        NaN
# 13  01S021        NaN        NaN        NaN        NaN
# 14  01S022        NaN        NaN        NaN        NaN
# 15  01S025        NaN        NaN        NaN        NaN
# 16  01S027        NaN        NaN        NaN        NaN
# ...

# %%
dim(truth)
# Out:
# [1] 209   5
